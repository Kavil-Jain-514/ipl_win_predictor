# %%
import numpy as np

# %%
import pandas as pd

# %%
match = pd.read_csv('matches.csv')

# %%
match.shape
# Out:
# (1024, 20)

# %% [markdown]
# match.head()

# %%
match.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# 0        Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1          Chennai Super Kings          Chennai Super Kings           bat
# 2             Rajasthan Royals             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4              Deccan Chargers              Deccan Chargers           bat
#
#                         winner   result  result_margin  target_runs  \
# 0        Kolkata Knight Riders     runs          140.0        223.0
# 1          Chennai Super Kings     runs           33.0        241.0
# 2             Delhi Daredevils  wickets            9.0        130.0
# 3  Royal Challengers Bangalore  wickets            5.0        166.0
# 4        Kolkata Knight Riders  wickets            5.0        111.0
#
#    target_overs super_over method    umpire1         umpire2
# 0          20.0          N    NaN  Asad Rauf     RE Koertzen
# 1          20.0          N    NaN  MR Benson      SL Shastri
# 2          20.0          N    NaN  Aleem Dar  GA Pratapkumar
# 3          20.0          N    NaN   SJ Davis       DJ Harper
# 4          20.0          N    NaN  BF Bowden     K Hariharan

# %%
delivery = pd.read_csv('deliveries.csv')

# %%
delivery.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# 0           1     legbyes          0              NaN            NaN     NaN
# 1           0         NaN          0              NaN            NaN     NaN
# 2           1       wides          0              NaN            NaN     NaN
# 3           0         NaN          0              NaN            NaN     NaN
# 4           0         NaN          0              NaN            NaN     NaN

# %% [markdown]
# We need to find the total score in the first inning of every match

# %%
total_score_df = delivery.groupby(['match_id','inning']).sum()['total_runs'].reset_index()
# Out:
# C:\Users\kavil\AppData\Local\Temp\ipykernel_23896\2553512226.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   total_score_df = delivery.groupby(['match_id','inning']).sum()['total_runs'].reset_index()

# %%
total_score_df = total_score_df[total_score_df['inning'] == 1]

# %%
total_score_df
# Out:
#       match_id  inning  total_runs
# 0       335982       1         222
# 2       335983       1         240
# 4       335984       1         129
# 6       335985       1         165
# 8       335986       1         110
# ...        ...     ...         ...
# 2065   1359544       1         197
# 2067   1370350       1         172
# 2069   1370351       1         182
# 2071   1370352       1         233
# 2073   1370353       1         214
#
# [1024 rows x 3 columns]

# %% [markdown]
# Add the total_runs column to match table using merge

# %%
match_df = match.merge(total_score_df[['match_id','total_runs']],left_on='id',right_on='match_id')

# %%
match_df
# Out:
#            id   season        city        date   match_type player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League     BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League      MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League     MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League      MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League       DJ Hussey
# ...       ...      ...         ...         ...          ...             ...
# 1019  1359544     2023   Bengaluru  2023-05-21       League    Shubman Gill
# 1020  1370350     2023     Chennai  2023-05-23  Qualifier 1      RD Gaikwad
# 1021  1370351     2023     Chennai  2023-05-24   Eliminator   Akash Madhwal
# 1022  1370352     2023   Ahmedabad  2023-05-26  Qualifier 2    Shubman Gill
# 1023  1370353     2023   Ahmedabad  2023-05-29        Final       DP Conway
#
#                                            venue                        team1  \
# 0                          M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1     Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                               Feroz Shah Kotla             Delhi Daredevils
# 3                               Wankhede Stadium               Mumbai Indians
# 4                                   Eden Gardens        Kolkata Knight Riders
# ...                                          ...                          ...
# 1019            M Chinnaswamy Stadium, Bengaluru  Royal Challengers Bangalore
# 1020    MA Chidambaram Stadium, Chepauk, Chennai          Chennai Super Kings
# 1021    MA Chidambaram Stadium, Chepauk, Chennai               Mumbai Indians
# 1022            Narendra Modi Stadium, Ahmedabad               Gujarat Titans
# 1023            Narendra Modi Stadium, Ahmedabad               Gujarat Titans
#
#                             team2                  toss_winner  ...   result  \
# 0           Kolkata Knight Riders  Royal Challengers Bangalore  ...     runs
# 1             Chennai Super Kings          Chennai Super Kings  ...     runs
# 2                Rajasthan Royals             Rajasthan Royals  ...  wickets
# 3     Royal Challengers Bangalore               Mumbai Indians  ...  wickets
# 4                 Deccan Chargers              Deccan Chargers  ...  wickets
# ...                           ...                          ...  ...      ...
# 1019               Gujarat Titans               Gujarat Titans  ...  wickets
# 1020               Gujarat Titans               Gujarat Titans  ...     runs
# 1021         Lucknow Super Giants               Mumbai Indians  ...     runs
# 1022               Mumbai Indians               Mumbai Indians  ...     runs
# 1023          Chennai Super Kings          Chennai Super Kings  ...  wickets
#
#      result_margin target_runs  target_overs  super_over  method  \
# 0            140.0       223.0          20.0           N     NaN
# 1             33.0       241.0          20.0           N     NaN
# 2              9.0       130.0          20.0           N     NaN
# 3              5.0       166.0          20.0           N     NaN
# 4              5.0       111.0          20.0           N     NaN
# ...            ...         ...           ...         ...     ...
# 1019           6.0       198.0          20.0           N     NaN
# 1020          15.0       173.0          20.0           N     NaN
# 1021          81.0       183.0          20.0           N     NaN
# 1022          62.0       234.0          20.0           N     NaN
# 1023           5.0       171.0          15.0           N     D/L
#
#            umpire1         umpire2 match_id total_runs
# 0        Asad Rauf     RE Koertzen   335982        222
# 1        MR Benson      SL Shastri   335983        240
# 2        Aleem Dar  GA Pratapkumar   335984        129
# 3         SJ Davis       DJ Harper   335985        165
# 4        BF Bowden     K Hariharan   335986        110
# ...            ...             ...      ...        ...
# 1019   Nitin Menon       VK Sharma  1359544        197
# 1020  AK Chaudhary     CB Gaffaney  1370350        172
# 1021  BNJ Oxenford       VK Sharma  1370351        182
# 1022   Nitin Menon       RJ Tucker  1370352        233
# 1023   Nitin Menon       RJ Tucker  1370353        214
#
# [1024 rows x 22 columns]

# %% [markdown]
# Filter out the matches of those teams who will not play IPL 2024
# We will combine Delhi Daredevils with Delhi Capitals, Deccan Chargers with Sunrisers Hyderabad, Kings XI Punjab with Punjab Kings and remove KTK, PWI, GL,RPSG teams.
# To remove teams, lets create an array with valid team names and then write a query to filter the teams which are not in the array.

# %%
teams = [
    'Sunrisers Hyderabad',
    'Mumbai Indians',
    'Royal Challengers Bangalore',
    'Kolkata Knight Riders',
    'Punjab Kings',
    'Chennai Super Kings',
    'Rajasthan Royals',
    'Delhi Capitals',
    'Lucknow Super Giants',
    'Gujarat Titans'
]

# %%
match_df['team1'] = match_df['team1'].str.replace('Delhi Daredevils', 'Delhi Capitals')
match_df['team2'] = match_df['team2'].str.replace('Delhi Daredevils', 'Delhi Capitals')
match_df['winner'] = match_df['winner'].str.replace('Delhi Daredevils', 'Delhi Capitals')
match_df['team1'] = match_df['team1'].str.replace('Deccan Chargers', 'Sunrisers Hyderabad')
match_df['team2'] = match_df['team2'].str.replace('Deccan Chargers', 'Sunrisers Hyderabad')
match_df['winner'] = match_df['winner'].str.replace('Deccan Chargers', 'Sunrisers Hyderabad')
match_df['team1'] = match_df['team1'].str.replace('Kings XI Punjab', 'Punjab Kings')
match_df['team2'] = match_df['team2'].str.replace('Kings XI Punjab', 'Punjab Kings')
match_df['team2'] = match_df['team2'].str.replace('Kings XI Punjab', 'Punjab Kings')
match_df['winner'] = match_df['winner'].str.replace('Kings XI Punjab', 'Punjab Kings')

# %%
match_df.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali                 Punjab Kings
# 2                            Feroz Shah Kotla               Delhi Capitals
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner  ...   result  \
# 0        Kolkata Knight Riders  Royal Challengers Bangalore  ...     runs
# 1          Chennai Super Kings          Chennai Super Kings  ...     runs
# 2             Rajasthan Royals             Rajasthan Royals  ...  wickets
# 3  Royal Challengers Bangalore               Mumbai Indians  ...  wickets
# 4          Sunrisers Hyderabad              Deccan Chargers  ...  wickets
#
#   result_margin target_runs  target_overs  super_over  method    umpire1  \
# 0         140.0       223.0          20.0           N     NaN  Asad Rauf
# 1          33.0       241.0          20.0           N     NaN  MR Benson
# 2           9.0       130.0          20.0           N     NaN  Aleem Dar
# 3           5.0       166.0          20.0           N     NaN   SJ Davis
# 4           5.0       111.0          20.0           N     NaN  BF Bowden
#
#           umpire2 match_id total_runs
# 0     RE Koertzen   335982        222
# 1      SL Shastri   335983        240
# 2  GA Pratapkumar   335984        129
# 3       DJ Harper   335985        165
# 4     K Hariharan   335986        110
#
# [5 rows x 22 columns]

# %%
match_df = match_df[match_df['team1'].isin(teams)]
match_df = match_df[match_df['team2'].isin(teams)]

# %%
match_df.shape
# Out:
# (909, 22)

# %%
match_df['method'].value_counts()
# Out:
# D/L    17
# Name: method, dtype: int64

# %% [markdown]
# Here we can remove 17 matches that was affected by rain

# %%
match_df = match_df[match_df['method'] != "D/L"]

# %%
match_df.shape
# Out:
# (892, 22)

# %%
match_df = match_df[['match_id', 'city', 'winner', 'total_runs']]

# %%
delivery_df = match_df.merge(delivery,on='match_id')

# %%
delivery_df
# Out:
#         match_id       city                 winner  total_runs_x  inning  \
# 0         335982  Bangalore  Kolkata Knight Riders           222       1
# 1         335982  Bangalore  Kolkata Knight Riders           222       1
# 2         335982  Bangalore  Kolkata Knight Riders           222       1
# 3         335982  Bangalore  Kolkata Knight Riders           222       1
# 4         335982  Bangalore  Kolkata Knight Riders           222       1
# ...          ...        ...                    ...           ...     ...
# 213874   1370352  Ahmedabad         Gujarat Titans           233       2
# 213875   1370352  Ahmedabad         Gujarat Titans           233       2
# 213876   1370352  Ahmedabad         Gujarat Titans           233       2
# 213877   1370352  Ahmedabad         Gujarat Titans           233       2
# 213878   1370352  Ahmedabad         Gujarat Titans           233       2
#
#                  batting_team                 bowling_team  over  ball  \
# 0       Kolkata Knight Riders  Royal Challengers Bangalore     0     1
# 1       Kolkata Knight Riders  Royal Challengers Bangalore     0     2
# 2       Kolkata Knight Riders  Royal Challengers Bangalore     0     3
# 3       Kolkata Knight Riders  Royal Challengers Bangalore     0     4
# 4       Kolkata Knight Riders  Royal Challengers Bangalore     0     5
# ...                       ...                          ...   ...   ...
# 213874         Mumbai Indians               Gujarat Titans    17     4
# 213875         Mumbai Indians               Gujarat Titans    17     5
# 213876         Mumbai Indians               Gujarat Titans    17     6
# 213877         Mumbai Indians               Gujarat Titans    18     1
# 213878         Mumbai Indians               Gujarat Titans    18     2
#
#                 batter     bowler     non_striker  batsman_runs  extra_runs  \
# 0           SC Ganguly    P Kumar     BB McCullum             0           1
# 1          BB McCullum    P Kumar      SC Ganguly             0           0
# 2          BB McCullum    P Kumar      SC Ganguly             0           1
# 3          BB McCullum    P Kumar      SC Ganguly             0           0
# 4          BB McCullum    P Kumar      SC Ganguly             0           0
# ...                ...        ...             ...           ...         ...
# 213874  JP Behrendorff   J Little     K Kartikeya             1           0
# 213875     K Kartikeya   J Little  JP Behrendorff             4           0
# 213876     K Kartikeya   J Little  JP Behrendorff             0           0
# 213877  JP Behrendorff  MM Sharma     K Kartikeya             1           0
# 213878     K Kartikeya  MM Sharma  JP Behrendorff             0           0
#
#         total_runs_y extras_type  is_wicket player_dismissed dismissal_kind  \
# 0                  1     legbyes          0              NaN            NaN
# 1                  0         NaN          0              NaN            NaN
# 2                  1       wides          0              NaN            NaN
# 3                  0         NaN          0              NaN            NaN
# 4                  0         NaN          0              NaN            NaN
# ...              ...         ...        ...              ...            ...
# 213874             1         NaN          0              NaN            NaN
# 213875             4         NaN          0              NaN            NaN
# 213876             0         NaN          0              NaN            NaN
# 213877             1         NaN          0              NaN            NaN
# 213878             0         NaN          1      K Kartikeya         caught
#
#           fielder
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 213874        NaN
# 213875        NaN
# 213876        NaN
# 213877        NaN
# 213878  DA Miller
#
# [213879 rows x 20 columns]

# %% [markdown]
# Now after merging the two rows, I need only the rows where innings value is 2 as I am finding the probability of chasing team to win the match

# %%
delivery_df = delivery_df[delivery_df['inning'] == 2]

# %%
delivery_df.shape
# Out:
# (103511, 20)

# %% [markdown]
# Now our main work is to find the runs_left and balls_left after every ball.

# %%
delivery_df['current_score'] = delivery_df.groupby('match_id').cumsum()['total_runs_y'] #totol_runs_at_every_ball
# Out:
# C:\Users\kavil\AppData\Local\Temp\ipykernel_23896\414881596.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.cumsum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   delivery_df['current_score'] = delivery_df.groupby('match_id').cumsum()['total_runs_y'] #totol_runs_at_every_ball
# C:\Users\kavil\AppData\Local\Temp\ipykernel_23896\414881596.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['current_score'] = delivery_df.groupby('match_id').cumsum()['total_runs_y'] #totol_runs_at_every_ball

# %%
delivery_df
# Out:
#         match_id       city                 winner  total_runs_x  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders           222       2
# 125       335982  Bangalore  Kolkata Knight Riders           222       2
# 126       335982  Bangalore  Kolkata Knight Riders           222       2
# 127       335982  Bangalore  Kolkata Knight Riders           222       2
# 128       335982  Bangalore  Kolkata Knight Riders           222       2
# ...          ...        ...                    ...           ...     ...
# 213874   1370352  Ahmedabad         Gujarat Titans           233       2
# 213875   1370352  Ahmedabad         Gujarat Titans           233       2
# 213876   1370352  Ahmedabad         Gujarat Titans           233       2
# 213877   1370352  Ahmedabad         Gujarat Titans           233       2
# 213878   1370352  Ahmedabad         Gujarat Titans           233       2
#
#                        batting_team           bowling_team  over  ball  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders     0     1
# 125     Royal Challengers Bangalore  Kolkata Knight Riders     0     2
# 126     Royal Challengers Bangalore  Kolkata Knight Riders     0     3
# 127     Royal Challengers Bangalore  Kolkata Knight Riders     0     4
# 128     Royal Challengers Bangalore  Kolkata Knight Riders     0     5
# ...                             ...                    ...   ...   ...
# 213874               Mumbai Indians         Gujarat Titans    17     4
# 213875               Mumbai Indians         Gujarat Titans    17     5
# 213876               Mumbai Indians         Gujarat Titans    17     6
# 213877               Mumbai Indians         Gujarat Titans    18     1
# 213878               Mumbai Indians         Gujarat Titans    18     2
#
#                 batter  ...     non_striker batsman_runs  extra_runs  \
# 124           R Dravid  ...        W Jaffer            1           0
# 125           W Jaffer  ...        R Dravid            0           1
# 126           W Jaffer  ...        R Dravid            0           0
# 127           W Jaffer  ...        R Dravid            1           0
# 128           R Dravid  ...        W Jaffer            1           0
# ...                ...  ...             ...          ...         ...
# 213874  JP Behrendorff  ...     K Kartikeya            1           0
# 213875     K Kartikeya  ...  JP Behrendorff            4           0
# 213876     K Kartikeya  ...  JP Behrendorff            0           0
# 213877  JP Behrendorff  ...     K Kartikeya            1           0
# 213878     K Kartikeya  ...  JP Behrendorff            0           0
#
#         total_runs_y  extras_type is_wicket  player_dismissed dismissal_kind  \
# 124                1          NaN         0               NaN            NaN
# 125                1        wides         0               NaN            NaN
# 126                0          NaN         0               NaN            NaN
# 127                1          NaN         0               NaN            NaN
# 128                1          NaN         0               NaN            NaN
# ...              ...          ...       ...               ...            ...
# 213874             1          NaN         0               NaN            NaN
# 213875             4          NaN         0               NaN            NaN
# 213876             0          NaN         0               NaN            NaN
# 213877             1          NaN         0               NaN            NaN
# 213878             0          NaN         1       K Kartikeya         caught
#
#           fielder current_score
# 124           NaN             1
# 125           NaN             2
# 126           NaN             2
# 127           NaN             3
# 128           NaN             4
# ...           ...           ...
# 213874        NaN           166
# 213875        NaN           170
# 213876        NaN           170
# 213877        NaN           171
# 213878  DA Miller           171
#
# [103511 rows x 21 columns]

# %%
delivery_df['runs_left'] = delivery_df['total_runs_x'] - delivery_df['current_score']
# Out:
# C:\Users\kavil\AppData\Local\Temp\ipykernel_23896\1162889266.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['runs_left'] = delivery_df['total_runs_x'] - delivery_df['current_score']

# %%
delivery_df
# Out:
#         match_id       city                 winner  total_runs_x  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders           222       2
# 125       335982  Bangalore  Kolkata Knight Riders           222       2
# 126       335982  Bangalore  Kolkata Knight Riders           222       2
# 127       335982  Bangalore  Kolkata Knight Riders           222       2
# 128       335982  Bangalore  Kolkata Knight Riders           222       2
# ...          ...        ...                    ...           ...     ...
# 213874   1370352  Ahmedabad         Gujarat Titans           233       2
# 213875   1370352  Ahmedabad         Gujarat Titans           233       2
# 213876   1370352  Ahmedabad         Gujarat Titans           233       2
# 213877   1370352  Ahmedabad         Gujarat Titans           233       2
# 213878   1370352  Ahmedabad         Gujarat Titans           233       2
#
#                        batting_team           bowling_team  over  ball  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders     0     1
# 125     Royal Challengers Bangalore  Kolkata Knight Riders     0     2
# 126     Royal Challengers Bangalore  Kolkata Knight Riders     0     3
# 127     Royal Challengers Bangalore  Kolkata Knight Riders     0     4
# 128     Royal Challengers Bangalore  Kolkata Knight Riders     0     5
# ...                             ...                    ...   ...   ...
# 213874               Mumbai Indians         Gujarat Titans    17     4
# 213875               Mumbai Indians         Gujarat Titans    17     5
# 213876               Mumbai Indians         Gujarat Titans    17     6
# 213877               Mumbai Indians         Gujarat Titans    18     1
# 213878               Mumbai Indians         Gujarat Titans    18     2
#
#                 batter  ... batsman_runs extra_runs  total_runs_y  \
# 124           R Dravid  ...            1          0             1
# 125           W Jaffer  ...            0          1             1
# 126           W Jaffer  ...            0          0             0
# 127           W Jaffer  ...            1          0             1
# 128           R Dravid  ...            1          0             1
# ...                ...  ...          ...        ...           ...
# 213874  JP Behrendorff  ...            1          0             1
# 213875     K Kartikeya  ...            4          0             4
# 213876     K Kartikeya  ...            0          0             0
# 213877  JP Behrendorff  ...            1          0             1
# 213878     K Kartikeya  ...            0          0             0
#
#         extras_type  is_wicket player_dismissed  dismissal_kind    fielder  \
# 124             NaN          0              NaN             NaN        NaN
# 125           wides          0              NaN             NaN        NaN
# 126             NaN          0              NaN             NaN        NaN
# 127             NaN          0              NaN             NaN        NaN
# 128             NaN          0              NaN             NaN        NaN
# ...             ...        ...              ...             ...        ...
# 213874          NaN          0              NaN             NaN        NaN
# 213875          NaN          0              NaN             NaN        NaN
# 213876          NaN          0              NaN             NaN        NaN
# 213877          NaN          0              NaN             NaN        NaN
# 213878          NaN          1      K Kartikeya          caught  DA Miller
#
#        current_score runs_left
# 124                1       221
# 125                2       220
# 126                2       220
# 127                3       219
# 128                4       218
# ...              ...       ...
# 213874           166        67
# 213875           170        63
# 213876           170        63
# 213877           171        62
# 213878           171        62
#
# [103511 rows x 22 columns]

# %%
delivery_df['balls_left'] = 126 - (delivery_df['over']*6 + delivery_df['ball'])
# Out:
# C:\Users\kavil\AppData\Local\Temp\ipykernel_23896\517047302.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['balls_left'] = 126 - (delivery_df['over']*6 + delivery_df['ball'])

# %%
delivery_df
# Out:
#         match_id       city                 winner  total_runs_x  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders           222       2
# 125       335982  Bangalore  Kolkata Knight Riders           222       2
# 126       335982  Bangalore  Kolkata Knight Riders           222       2
# 127       335982  Bangalore  Kolkata Knight Riders           222       2
# 128       335982  Bangalore  Kolkata Knight Riders           222       2
# ...          ...        ...                    ...           ...     ...
# 213874   1370352  Ahmedabad         Gujarat Titans           233       2
# 213875   1370352  Ahmedabad         Gujarat Titans           233       2
# 213876   1370352  Ahmedabad         Gujarat Titans           233       2
# 213877   1370352  Ahmedabad         Gujarat Titans           233       2
# 213878   1370352  Ahmedabad         Gujarat Titans           233       2
#
#                        batting_team           bowling_team  over  ball  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders     0     1
# 125     Royal Challengers Bangalore  Kolkata Knight Riders     0     2
# 126     Royal Challengers Bangalore  Kolkata Knight Riders     0     3
# 127     Royal Challengers Bangalore  Kolkata Knight Riders     0     4
# 128     Royal Challengers Bangalore  Kolkata Knight Riders     0     5
# ...                             ...                    ...   ...   ...
# 213874               Mumbai Indians         Gujarat Titans    17     4
# 213875               Mumbai Indians         Gujarat Titans    17     5
# 213876               Mumbai Indians         Gujarat Titans    17     6
# 213877               Mumbai Indians         Gujarat Titans    18     1
# 213878               Mumbai Indians         Gujarat Titans    18     2
#
#                 batter  ... extra_runs total_runs_y  extras_type  is_wicket  \
# 124           R Dravid  ...          0            1          NaN          0
# 125           W Jaffer  ...          1            1        wides          0
# 126           W Jaffer  ...          0            0          NaN          0
# 127           W Jaffer  ...          0            1          NaN          0
# 128           R Dravid  ...          0            1          NaN          0
# ...                ...  ...        ...          ...          ...        ...
# 213874  JP Behrendorff  ...          0            1          NaN          0
# 213875     K Kartikeya  ...          0            4          NaN          0
# 213876     K Kartikeya  ...          0            0          NaN          0
# 213877  JP Behrendorff  ...          0            1          NaN          0
# 213878     K Kartikeya  ...          0            0          NaN          1
#
#         player_dismissed dismissal_kind    fielder current_score runs_left  \
# 124                  NaN            NaN        NaN             1       221
# 125                  NaN            NaN        NaN             2       220
# 126                  NaN            NaN        NaN             2       220
# 127                  NaN            NaN        NaN             3       219
# 128                  NaN            NaN        NaN             4       218
# ...                  ...            ...        ...           ...       ...
# 213874               NaN            NaN        NaN           166        67
# 213875               NaN            NaN        NaN           170        63
# 213876               NaN            NaN        NaN           170        63
# 213877               NaN            NaN        NaN           171        62
# 213878       K Kartikeya         caught  DA Miller           171        62
#
#        balls_left
# 124           125
# 125           124
# 126           123
# 127           122
# 128           121
# ...           ...
# 213874         20
# 213875         19
# 213876         18
# 213877         17
# 213878         16
#
# [103511 rows x 23 columns]

# %% [markdown]
# Now we need another attribute called wicket_left which represents how many wickets are left at a particular ball in a match.

# %% [markdown]
# So we start by converting the values of player_dismissed, if NaN then "0" else "1". And then we group by the matchid and calculate the wickets left.

# %%
delivery_df['player_dismissed'] = delivery_df['player_dismissed'].fillna("0")
delivery_df['player_dismissed'] = delivery_df['player_dismissed'].apply(lambda x:x if x == "0" else "1")
delivery_df['player_dismissed'] = delivery_df['player_dismissed'].astype('int')
wickets = delivery_df.groupby('match_id').cumsum()['player_dismissed'].values
delivery_df['wickets_left'] = 10 - wickets
delivery_df.head()
# Out:
# C:\Users\kavil\AppData\Local\Temp\ipykernel_23896\1997724059.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['player_dismissed'] = delivery_df['player_dismissed'].fillna("0")
# C:\Users\kavil\AppData\Local\Temp\ipykernel_23896\1997724059.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['player_dismissed'] = delivery_df['player_dismissed'].apply(lambda x:x if x == "0" else "1")
# C:\Users\kavil\AppData\Local\Temp\ipykernel_23896\1997724059.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['player_dismissed'] = delivery_df['player_dismissed'].astype('int')
# C:\Users\kavil\AppData\Local\Temp\ipykernel_23896\1997724059.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.cumsum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   wickets = delivery_df.groupby('match_id').cumsum()['player_dismissed'].values
# C:\Users\kavil\AppData\Local\Temp\ipykernel_23896\1997724059.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['wickets_left'] = 10 - wickets
#      match_id       city                 winner  total_runs_x  inning  \
# 124    335982  Bangalore  Kolkata Knight Riders           222       2
# 125    335982  Bangalore  Kolkata Knight Riders           222       2
# 126    335982  Bangalore  Kolkata Knight Riders           222       2
# 127    335982  Bangalore  Kolkata Knight Riders           222       2
# 128    335982  Bangalore  Kolkata Knight Riders           222       2
#
#                     batting_team           bowling_team  over  ball    batter  \
# 124  Royal Challengers Bangalore  Kolkata Knight Riders     0     1  R Dravid
# 125  Royal Challengers Bangalore  Kolkata Knight Riders     0     2  W Jaffer
# 126  Royal Challengers Bangalore  Kolkata Knight Riders     0     3  W Jaffer
# 127  Royal Challengers Bangalore  Kolkata Knight Riders     0     4  W Jaffer
# 128  Royal Challengers Bangalore  Kolkata Knight Riders     0     5  R Dravid
#
#      ... total_runs_y extras_type  is_wicket  player_dismissed  \
# 124  ...            1         NaN          0                 0
# 125  ...            1       wides          0                 0
# 126  ...            0         NaN          0                 0
# 127  ...            1         NaN          0                 0
# 128  ...            1         NaN          0                 0
#
#      dismissal_kind fielder  current_score  runs_left balls_left wickets_left
# 124             NaN     NaN              1        221        125           10
# 125             NaN     NaN              2        220        124           10
# 126             NaN     NaN              2        220        123           10
# 127             NaN     NaN              3        219        122           10
# 128             NaN     NaN              4        218        121           10
#
# [5 rows x 24 columns]

# %%
delivery_df
# Out:
#         match_id       city                 winner  total_runs_x  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders           222       2
# 125       335982  Bangalore  Kolkata Knight Riders           222       2
# 126       335982  Bangalore  Kolkata Knight Riders           222       2
# 127       335982  Bangalore  Kolkata Knight Riders           222       2
# 128       335982  Bangalore  Kolkata Knight Riders           222       2
# ...          ...        ...                    ...           ...     ...
# 213874   1370352  Ahmedabad         Gujarat Titans           233       2
# 213875   1370352  Ahmedabad         Gujarat Titans           233       2
# 213876   1370352  Ahmedabad         Gujarat Titans           233       2
# 213877   1370352  Ahmedabad         Gujarat Titans           233       2
# 213878   1370352  Ahmedabad         Gujarat Titans           233       2
#
#                        batting_team           bowling_team  over  ball  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders     0     1
# 125     Royal Challengers Bangalore  Kolkata Knight Riders     0     2
# 126     Royal Challengers Bangalore  Kolkata Knight Riders     0     3
# 127     Royal Challengers Bangalore  Kolkata Knight Riders     0     4
# 128     Royal Challengers Bangalore  Kolkata Knight Riders     0     5
# ...                             ...                    ...   ...   ...
# 213874               Mumbai Indians         Gujarat Titans    17     4
# 213875               Mumbai Indians         Gujarat Titans    17     5
# 213876               Mumbai Indians         Gujarat Titans    17     6
# 213877               Mumbai Indians         Gujarat Titans    18     1
# 213878               Mumbai Indians         Gujarat Titans    18     2
#
#                 batter  ... total_runs_y extras_type  is_wicket  \
# 124           R Dravid  ...            1         NaN          0
# 125           W Jaffer  ...            1       wides          0
# 126           W Jaffer  ...            0         NaN          0
# 127           W Jaffer  ...            1         NaN          0
# 128           R Dravid  ...            1         NaN          0
# ...                ...  ...          ...         ...        ...
# 213874  JP Behrendorff  ...            1         NaN          0
# 213875     K Kartikeya  ...            4         NaN          0
# 213876     K Kartikeya  ...            0         NaN          0
# 213877  JP Behrendorff  ...            1         NaN          0
# 213878     K Kartikeya  ...            0         NaN          1
#
#         player_dismissed  dismissal_kind    fielder  current_score  runs_left  \
# 124                    0             NaN        NaN              1        221
# 125                    0             NaN        NaN              2        220
# 126                    0             NaN        NaN              2        220
# 127                    0             NaN        NaN              3        219
# 128                    0             NaN        NaN              4        218
# ...                  ...             ...        ...            ...        ...
# 213874                 0             NaN        NaN            166         67
# 213875                 0             NaN        NaN            170         63
# 213876                 0             NaN        NaN            170         63
# 213877                 0             NaN        NaN            171         62
# 213878                 1          caught  DA Miller            171         62
#
#        balls_left wickets_left
# 124           125           10
# 125           124           10
# 126           123           10
# 127           122           10
# 128           121           10
# ...           ...          ...
# 213874         20            1
# 213875         19            1
# 213876         18            1
# 213877         17            1
# 213878         16            0
#
# [103511 rows x 24 columns]

# %% [markdown]
# The last two attributes would be current_runRate and required_runRate

# %%
delivery_df['crr'] = (delivery_df['current_score']*6)/(120 - delivery_df['balls_left'])
# Out:
# C:\Users\kavil\AppData\Local\Temp\ipykernel_23896\2048085250.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['crr'] = (delivery_df['current_score']*6)/(120 - delivery_df['balls_left'])

# %%
delivery_df['rrr'] = (delivery_df['runs_left']*6)/delivery_df['balls_left']
# Out:
# C:\Users\kavil\AppData\Local\Temp\ipykernel_23896\2241449921.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['rrr'] = (delivery_df['runs_left']*6)/delivery_df['balls_left']

# %%
delivery_df
# Out:
#         match_id       city                 winner  total_runs_x  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders           222       2
# 125       335982  Bangalore  Kolkata Knight Riders           222       2
# 126       335982  Bangalore  Kolkata Knight Riders           222       2
# 127       335982  Bangalore  Kolkata Knight Riders           222       2
# 128       335982  Bangalore  Kolkata Knight Riders           222       2
# ...          ...        ...                    ...           ...     ...
# 213874   1370352  Ahmedabad         Gujarat Titans           233       2
# 213875   1370352  Ahmedabad         Gujarat Titans           233       2
# 213876   1370352  Ahmedabad         Gujarat Titans           233       2
# 213877   1370352  Ahmedabad         Gujarat Titans           233       2
# 213878   1370352  Ahmedabad         Gujarat Titans           233       2
#
#                        batting_team           bowling_team  over  ball  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders     0     1
# 125     Royal Challengers Bangalore  Kolkata Knight Riders     0     2
# 126     Royal Challengers Bangalore  Kolkata Knight Riders     0     3
# 127     Royal Challengers Bangalore  Kolkata Knight Riders     0     4
# 128     Royal Challengers Bangalore  Kolkata Knight Riders     0     5
# ...                             ...                    ...   ...   ...
# 213874               Mumbai Indians         Gujarat Titans    17     4
# 213875               Mumbai Indians         Gujarat Titans    17     5
# 213876               Mumbai Indians         Gujarat Titans    17     6
# 213877               Mumbai Indians         Gujarat Titans    18     1
# 213878               Mumbai Indians         Gujarat Titans    18     2
#
#                 batter  ... is_wicket player_dismissed  dismissal_kind  \
# 124           R Dravid  ...         0                0             NaN
# 125           W Jaffer  ...         0                0             NaN
# 126           W Jaffer  ...         0                0             NaN
# 127           W Jaffer  ...         0                0             NaN
# 128           R Dravid  ...         0                0             NaN
# ...                ...  ...       ...              ...             ...
# 213874  JP Behrendorff  ...         0                0             NaN
# 213875     K Kartikeya  ...         0                0             NaN
# 213876     K Kartikeya  ...         0                0             NaN
# 213877  JP Behrendorff  ...         0                0             NaN
# 213878     K Kartikeya  ...         1                1          caught
#
#           fielder  current_score runs_left  balls_left  wickets_left  \
# 124           NaN              1       221         125            10
# 125           NaN              2       220         124            10
# 126           NaN              2       220         123            10
# 127           NaN              3       219         122            10
# 128           NaN              4       218         121            10
# ...           ...            ...       ...         ...           ...
# 213874        NaN            166        67          20             1
# 213875        NaN            170        63          19             1
# 213876        NaN            170        63          18             1
# 213877        NaN            171        62          17             1
# 213878  DA Miller            171        62          16             0
#
#               crr        rrr
# 124     -1.200000  10.608000
# 125     -3.000000  10.645161
# 126     -4.000000  10.731707
# 127     -9.000000  10.770492
# 128    -24.000000  10.809917
# ...           ...        ...
# 213874   9.960000  20.100000
# 213875  10.099010  19.894737
# 213876  10.000000  21.000000
# 213877   9.961165  21.882353
# 213878   9.865385  23.250000
#
# [103511 rows x 26 columns]

# %% [markdown]
# A last row, winner row where the team won would be recorded

# %%
def result(row):
    return 1 if row['batting_team'] == row['winner'] else 0

# %%
delivery_df['result'] = delivery_df.apply(result,axis=1)
# Out:
# C:\Users\kavil\AppData\Local\Temp\ipykernel_23896\955537649.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['result'] = delivery_df.apply(result,axis=1)

# %%
final_df = delivery_df[['batting_team','bowling_team','city','runs_left','balls_left','wickets_left','total_runs_x','crr','rrr','result']]

# %%
final_df = final_df.sample(final_df.shape[0]) #shuffled (since all balls of the matches are grouped)

# %%
final_df.sample()
# Out:
#           batting_team         bowling_team    city  runs_left  balls_left  \
# 115606  Mumbai Indians  Sunrisers Hyderabad  Mumbai         60          52
#
#         wickets_left  total_runs_x       crr       rrr  result
# 115606             7           158  8.647059  6.923077       1

# %%
final_df.isnull().sum()
# Out:
# batting_team       0
# bowling_team       0
# city            6012
# runs_left          0
# balls_left         0
# wickets_left       0
# total_runs_x       0
# crr               27
# rrr                0
# result             0
# dtype: int64

# %%
final_df.dropna(inplace=True)

# %%
final_df
# Out:
#                        batting_team                 bowling_team         city  \
# 194510        Kolkata Knight Riders         Lucknow Super Giants  Navi Mumbai
# 31568              Rajasthan Royals              Deccan Chargers    Ahmedabad
# 429                 Kings XI Punjab          Chennai Super Kings   Chandigarh
# 90274           Sunrisers Hyderabad  Royal Challengers Bangalore    Hyderabad
# 36950               Kings XI Punjab             Delhi Daredevils        Delhi
# ...                             ...                          ...          ...
# 94061              Delhi Daredevils          Chennai Super Kings      Chennai
# 175427               Delhi Capitals               Mumbai Indians      Sharjah
# 47991              Rajasthan Royals          Chennai Super Kings       Jaipur
# 125555  Royal Challengers Bangalore             Delhi Daredevils    Bengaluru
# 135930               Mumbai Indians               Delhi Capitals       Mumbai
#
#         runs_left  balls_left  wickets_left  total_runs_x        crr  \
# 194510         38          19             4           210  10.217822
# 31568          79          78             9           148   9.857143
# 429            99          48             8           240  11.750000
# 90274         156         122            10           160 -12.000000
# 36950          25          39             8           111   6.370370
# ...           ...         ...           ...           ...        ...
# 94061         135         113            10           150  12.857143
# 175427         26          31             4           129   6.943820
# 47991          80          33             5           196   8.000000
# 125555         67          52             7           174   9.441176
# 135930         60          26             3           213   9.765957
#
#               rrr  result
# 194510  12.000000       0
# 31568    6.076923       1
# 429     12.375000       0
# 90274    7.672131       1
# 36950    3.846154       0
# ...           ...     ...
# 94061    7.168142       0
# 175427   5.032258       1
# 47991   14.545455       0
# 125555   7.730769       1
# 135930  13.846154       0
#
# [97475 rows x 10 columns]

# %%
final_df = final_df[final_df['balls_left'] != 0]

# %%
final_df = final_df[final_df['crr'] != np.inf]

# %%
final_df
# Out:
#                        batting_team                 bowling_team         city  \
# 194510        Kolkata Knight Riders         Lucknow Super Giants  Navi Mumbai
# 31568              Rajasthan Royals              Deccan Chargers    Ahmedabad
# 429                 Kings XI Punjab          Chennai Super Kings   Chandigarh
# 90274           Sunrisers Hyderabad  Royal Challengers Bangalore    Hyderabad
# 36950               Kings XI Punjab             Delhi Daredevils        Delhi
# ...                             ...                          ...          ...
# 94061              Delhi Daredevils          Chennai Super Kings      Chennai
# 175427               Delhi Capitals               Mumbai Indians      Sharjah
# 47991              Rajasthan Royals          Chennai Super Kings       Jaipur
# 125555  Royal Challengers Bangalore             Delhi Daredevils    Bengaluru
# 135930               Mumbai Indians               Delhi Capitals       Mumbai
#
#         runs_left  balls_left  wickets_left  total_runs_x        crr  \
# 194510         38          19             4           210  10.217822
# 31568          79          78             9           148   9.857143
# 429            99          48             8           240  11.750000
# 90274         156         122            10           160 -12.000000
# 36950          25          39             8           111   6.370370
# ...           ...         ...           ...           ...        ...
# 94061         135         113            10           150  12.857143
# 175427         26          31             4           129   6.943820
# 47991          80          33             5           196   8.000000
# 125555         67          52             7           174   9.441176
# 135930         60          26             3           213   9.765957
#
#               rrr  result
# 194510  12.000000       0
# 31568    6.076923       1
# 429     12.375000       0
# 90274    7.672131       1
# 36950    3.846154       0
# ...           ...     ...
# 94061    7.168142       0
# 175427   5.032258       1
# 47991   14.545455       0
# 125555   7.730769       1
# 135930  13.846154       0
#
# [96660 rows x 10 columns]

# %% [markdown]
# ## Model Building

# %%
X = final_df.iloc[:,:-1]
y = final_df.iloc[:,-1]
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#                  batting_team                 bowling_team        city  \
# 89544   Kolkata Knight Riders          Sunrisers Hyderabad   Hyderabad
# 108553    Sunrisers Hyderabad               Mumbai Indians   Hyderabad
# 67358     Chennai Super Kings              Kings XI Punjab  Chandigarh
# 176957       Rajasthan Royals        Kolkata Knight Riders     Sharjah
# 167534    Sunrisers Hyderabad                 Punjab Kings     Chennai
# ...                       ...                          ...         ...
# 163812    Sunrisers Hyderabad               Delhi Capitals   Abu Dhabi
# 110713  Kolkata Knight Riders  Royal Challengers Bangalore   Bangalore
# 115550         Mumbai Indians          Sunrisers Hyderabad      Mumbai
# 107440    Sunrisers Hyderabad  Royal Challengers Bangalore   Bangalore
# 148803         Mumbai Indians          Chennai Super Kings     Chennai
#
#         runs_left  balls_left  wickets_left  total_runs_x        crr  \
# 89544         130         108             9           142   6.000000
# 108553        141         125            10           142  -1.200000
# 67358         103          92            10           138   7.500000
# 176957        168         118             8           171   9.000000
# 167534          0          14             9           120   6.792453
# ...           ...         ...           ...           ...        ...
# 163812        127          73             7           189   7.914894
# 110713        177         117             9           185  16.000000
# 115550        130         108            10           158  14.000000
# 107440        121          54             5           227   9.636364
# 148803         16          31             6           131   7.752809
#
#               rrr
# 89544    7.222222
# 108553   6.768000
# 67358    6.717391
# 176957   8.542373
# 167534   0.000000
# ...           ...
# 163812  10.438356
# 110713   9.076923
# 115550   7.222222
# 107440  13.444444
# 148803   3.096774
#
# [77328 rows x 9 columns]

# %% [markdown]
# #We have 3 columns batting_team, bowling_team and city as string so we need to apply one-hot encoding

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse_output=False,drop='first'),['batting_team','bowling_team','city'])
]
,remainder='passthrough')

# %%
X_train
# Out:
#                  batting_team                 bowling_team        city  \
# 89544   Kolkata Knight Riders          Sunrisers Hyderabad   Hyderabad
# 108553    Sunrisers Hyderabad               Mumbai Indians   Hyderabad
# 67358     Chennai Super Kings              Kings XI Punjab  Chandigarh
# 176957       Rajasthan Royals        Kolkata Knight Riders     Sharjah
# 167534    Sunrisers Hyderabad                 Punjab Kings     Chennai
# ...                       ...                          ...         ...
# 163812    Sunrisers Hyderabad               Delhi Capitals   Abu Dhabi
# 110713  Kolkata Knight Riders  Royal Challengers Bangalore   Bangalore
# 115550         Mumbai Indians          Sunrisers Hyderabad      Mumbai
# 107440    Sunrisers Hyderabad  Royal Challengers Bangalore   Bangalore
# 148803         Mumbai Indians          Chennai Super Kings     Chennai
#
#         runs_left  balls_left  wickets_left  total_runs_x        crr  \
# 89544         130         108             9           142   6.000000
# 108553        141         125            10           142  -1.200000
# 67358         103          92            10           138   7.500000
# 176957        168         118             8           171   9.000000
# 167534          0          14             9           120   6.792453
# ...           ...         ...           ...           ...        ...
# 163812        127          73             7           189   7.914894
# 110713        177         117             9           185  16.000000
# 115550        130         108            10           158  14.000000
# 107440        121          54             5           227   9.636364
# 148803         16          31             6           131   7.752809
#
#               rrr
# 89544    7.222222
# 108553   6.768000
# 67358    6.717391
# 176957   8.542373
# 167534   0.000000
# ...           ...
# 163812  10.438356
# 110713   9.076923
# 115550   7.222222
# 107440  13.444444
# 148803   3.096774
#
# [77328 rows x 9 columns]

# %%
#Logistics Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.pipeline import Pipeline

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',LogisticRegression(solver='liblinear'))
])

# %%
pipe2 = Pipeline(steps=[
    ('step1',trf),
    ('step2', RandomForestClassifier())
])

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
pipe2.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', RandomForestClassifier())])

# %%
X_train.describe()
# Out:
#           runs_left    balls_left  wickets_left  total_runs_x           crr  \
# count  77328.000000  77328.000000  77328.000000  77328.000000  77328.000000
# mean      92.080928     68.003039      7.488426    166.772825      8.865475
# std       50.038445     33.227172      2.163167     29.379553      7.395021
# min       -6.000000      4.000000      0.000000     62.000000   -132.000000
# 25%       53.000000     40.000000      6.000000    148.000000      7.235294
# 50%       91.000000     69.000000      8.000000    167.000000      8.597938
# 75%      129.000000     97.000000      9.000000    187.000000     10.200000
# max      257.000000    125.000000     10.000000    257.000000    162.000000
#
#                 rrr
# count  77328.000000
# mean       8.475805
# std        4.333670
# min       -9.000000
# 25%        6.444444
# 50%        8.093023
# 75%        9.795918
# max      102.000000

# %%
y_pred = pipe.predict(X_test)

# %%
Y_pred2 = pipe2.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.8539726877715704

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,Y_pred2)
# Out:
# 0.9994309952410511

# %%
X_test
# Out:
#                  batting_team                 bowling_team       city  \
# 106050         Mumbai Indians          Sunrisers Hyderabad  Hyderabad
# 189385         Delhi Capitals         Lucknow Super Giants     Mumbai
# 100566       Delhi Daredevils              Kings XI Punjab      Delhi
# 180895         Delhi Capitals               Gujarat Titans       Pune
# 109355         Mumbai Indians             Delhi Daredevils      Delhi
# ...                       ...                          ...        ...
# 28442        Delhi Daredevils               Mumbai Indians      Delhi
# 213324         Gujarat Titans          Chennai Super Kings    Chennai
# 100532       Delhi Daredevils              Kings XI Punjab      Delhi
# 144630    Chennai Super Kings  Royal Challengers Bangalore  Bengaluru
# 42852   Kolkata Knight Riders             Rajasthan Royals     Jaipur
#
#         runs_left  balls_left  wickets_left  total_runs_x        crr  \
# 106050         10          50            10           113   8.828571
# 189385        127          87             8           195  12.363636
# 100566         29          59            10           118   8.754098
# 180895        110          80             7           171   9.150000
# 109355         44          28             6           164   7.826087
# ...           ...         ...           ...           ...        ...
# 28442         133          65             5           218   9.272727
# 213324        120          78             8           172   7.428571
# 100532         77          90            10           118   8.200000
# 144630        104          66             6           161   6.333333
# 42852         101          92             9           159  12.428571
#
#               rrr
# 106050   1.200000
# 189385   8.758621
# 100566   2.949153
# 180895   8.250000
# 109355   9.428571
# ...           ...
# 28442   12.276923
# 213324   9.230769
# 100532   5.133333
# 144630   9.454545
# 42852    6.586957
#
# [19332 rows x 9 columns]

# %%
pipe2.predict_proba(X_test)[19329]
# Out:
# array([1., 0.])

# %%
pipe.predict_proba(X_test)[19329]
# Out:
# array([0.99554854, 0.00445146])

# %%
delivery_df = delivery_df[delivery_df['crr'] != np.inf]

# %%
#Let's create a function that uses this lR algorithm for a one full match and analyze the situation atv each stage

# %%
def match_progression(x_df,match_id,pipe):
    match = x_df[x_df['match_id'] == match_id]
    match = match[(match['ball'] == 6)]
    temp_df = match[['batting_team','bowling_team','city','runs_left','balls_left','wickets_left','total_runs_x','crr','rrr']].dropna()
    temp_df = temp_df[temp_df['balls_left'] != 0]
    if temp_df.empty:
        raise ValueError("Input dataframe is empty. Please check the input data.")
    result = pipe.predict_proba(temp_df)

    temp_df['lose'] = np.round(result.T[0]*100,1)
    temp_df['win'] = np.round(result.T[1]*100,1)
    temp_df['end_of_over'] = range(1,temp_df.shape[0]+1)
    
    target = temp_df['total_runs_x'].values[0]
    runs = list(temp_df['runs_left'].values)
    new_runs = runs[:]
    runs.insert(0,target)
    temp_df['runs_after_over'] = np.array(runs)[:-1] - np.array(new_runs)
    wickets = list(temp_df['wickets_left'].values)
    new_wickets = wickets[:]
    new_wickets.insert(0,10)
    wickets.append(0)
    w = np.array(wickets)
    nw = np.array(new_wickets)
    temp_df['wickets_in_over'] = (nw - w)[0:temp_df.shape[0]]
    
    print("Target-",target)
    temp_df = temp_df[['end_of_over','runs_after_over','wickets_in_over','lose','win']]
    return temp_df,target

# %%
temp_df,target = match_progression(delivery_df,733971,pipe)
temp_df
# Out:
# Target- 148
#        end_of_over  runs_after_over  wickets_in_over  lose   win
# 84420            1               16                0  11.0  89.0
# 84426            2                4                1  17.9  82.1
# 84432            3               15                0  11.9  88.1
# 84438            4                3                1  19.8  80.2
# 84444            5                1                2  47.1  52.9
# 84450            6               10                0  40.4  59.6
# 84456            7               10                0  33.7  66.3
# 84462            8                5                0  32.9  67.1
# 84468            9                2                1  50.1  49.9
# 84474           10                3                0  53.1  46.9
# 84480           11                5                0  54.0  46.0
# 84486           12               10                0  46.8  53.2
# 84492           13                4                1  64.5  35.5
# 84498           14                3                1  81.6  18.4
# 84504           15               19                0  58.4  41.6
# 84510           16                4                2  85.5  14.5

# %%
unique_id = delivery_df['match_id'].unique()

# %%
unique_id
# Out:
# array([ 335982,  335983,  335984,  335985,  335986,  335987,  335988,
#         335989,  335990,  335991,  335992,  335993,  335994,  335995,
#         335996,  335997,  335998,  335999,  336000,  336001,  336003,
#         336034,  336004,  336005,  336006,  336007,  336008,  336009,
#         336010,  336011,  336013,  336014,  336015,  336016,  336017,
#         336018,  336020,  336021,  336023,  336024,  336026,  336027,
#         336028,  336029,  336031,  336032,  336033,  336002,  336035,
#         336036,  336037,  336012,  336019,  336038,  336039,  336040,
#         392181,  392182,  392184,  392185,  392188,  392189,  392190,
#         392191,  392192,  392194,  392195,  392196,  392197,  392198,
#         392199,  392200,  392201,  392202,  392203,  392204,  392205,
#         392206,  392207,  392208,  392209,  392210,  392211,  392212,
#         392213,  392215,  392216,  392217,  392218,  392219,  392220,
#         392221,  392222,  392223,  392224,  392225,  392226,  392227,
#         392228,  392229,  392230,  392231,  392232,  392233,  392234,
#         392235,  392236,  392237,  392238,  392239,  419106,  419107,
#         419108,  419109,  419110,  419111,  419112,  419113,  419114,
#         419115,  419116,  419117,  419118,  419119,  419120,  419121,
#         419122,  419123,  419124,  419125,  419128,  419126,  419127,
#         419129,  419130,  419131,  419132,  419133,  419134,  419135,
#         419136,  419137,  419138,  419139,  419140,  419141,  419142,
#         419143,  419144,  419145,  419146,  419147,  419148,  419149,
#         419150,  419151,  419152,  419153,  419154,  419155,  419156,
#         419157,  419158,  419159,  419160,  419161,  419162,  419163,
#         419164,  419165,  501198,  501199,  501201,  501203,  501204,
#         501205,  501206,  501208,  501209,  501211,  501212,  501214,
#         501216,  501220,  501221,  501222,  501223,  501224,  501227,
#         501230,  501231,  501234,  501236,  501237,  501239,  501240,
#         501243,  501244,  501246,  501249,  501251,  501252,  501253,
#         501256,  501257,  501260,  501263,  501264,  501266,  501267,
#         501268,  501269,  501270,  501271,  548306,  548307,  548309,
#         548310,  548311,  548312,  548314,  548315,  548316,  548317,
#         548318,  548320,  548323,  548324,  548325,  548326,  548328,
#         548321,  548331,  548332,  548334,  548335,  548336,  548339,
#         548342,  548343,  548344,  548345,  548346,  548347,  548349,
#         548350,  548352,  548354,  548355,  548356,  548357,  548359,
#         548360,  548329,  548361,  548363,  548364,  548366,  548367,
#         548368,  548369,  548370,  548371,  548372,  548373,  548374,
#         548376,  548377,  548378,  548379,  548380,  548381,  597998,
#         597999,  598001,  598002,  598004,  598005,  598006,  598048,
#         598007,  598008,  598010,  598012,  598013,  598014,  598016,
#         598017,  598019,  598020,  598021,  598022,  598023,  598024,
#         598026,  598059,  598029,  598030,  598031,  598032,  598033,
#         598034,  598036,  598037,  598039,  598040,  598041,  598043,
#         598044,  598046,  598064,  598049,  598050,  598051,  598052,
#         598054,  598056,  598057,  598058,  598060,  598045,  598062,
#         598063,  598028,  598065,  598066,  598068,  598069,  598070,
#         598071,  598072,  598073,  729279,  729281,  729283,  729285,
#         729287,  729289,  729291,  729293,  729295,  729297,  729299,
#         729301,  729303,  729305,  729307,  729309,  729311,  729313,
#         729315,  729317,  733971,  733973,  733975,  733977,  733979,
#         733981,  733983,  733985,  733987,  733989,  733991,  733995,
#         733997,  733999,  734001,  734003,  734005,  734007,  734009,
#         734011,  734013,  734015,  734017,  734019,  734021,  734023,
#         734025,  734027,  734029,  734031,  734033,  734035,  734037,
#         734039,  734041,  734043,  734045,  734047,  734049,  829705,
#         829707,  829709,  829711,  829713,  829715,  829717,  829719,
#         829721,  829725,  829727,  829729,  829731,  829733,  829735,
#         829737,  829739,  829741,  829745,  829747,  829749,  829751,
#         829753,  829757,  829759,  829765,  829723,  829767,  829769,
#         829771,  829773,  829775,  829777,  829779,  829781,  829783,
#         829785,  829761,  829787,  829789,  829791,  829793,  829795,
#         829797,  829799,  829801,  829803,  829805,  829809,  829811,
#         829813,  829815,  829817,  829819,  829821,  829823,  980903,
#         980907,  980909,  980913,  980915,  980921,  980923,  980925,
#         980927,  980933,  980935,  980941,  980947,  980951,  980953,
#         980959,  980963,  980971,  980973,  980977,  980981,  980983,
#         980985,  980991,  980993,  980995,  981003,  981009,  981011,
#         981015,  981019, 1082591, 1082595, 1082597, 1082598, 1082600,
#        1082601, 1082602, 1082604, 1082605, 1082608, 1082609, 1082611,
#        1082612, 1082614, 1082617, 1082622, 1082623, 1082626, 1082627,
#        1082628, 1082630, 1082633, 1082635, 1082636, 1082638, 1082639,
#        1082641, 1082644, 1082646, 1082649, 1136561, 1136562, 1136563,
#        1136564, 1136565, 1136567, 1136568, 1136569, 1136570, 1136571,
#        1136572, 1136573, 1136574, 1136575, 1136576, 1136577, 1136579,
#        1136580, 1136581, 1136582, 1136583, 1136584, 1136585, 1136586,
#        1136587, 1136588, 1136589, 1136590, 1136591, 1136593, 1136594,
#        1136595, 1136596, 1136597, 1136598, 1136599, 1136600, 1136601,
#        1136602, 1136603, 1136604, 1136605, 1136606, 1136607, 1136608,
#        1136609, 1136610, 1136611, 1136612, 1136613, 1136614, 1136615,
#        1136616, 1136617, 1136618, 1136619, 1136620, 1175356, 1175357,
#        1175358, 1175359, 1175360, 1175361, 1175362, 1175363, 1175364,
#        1175365, 1175366, 1175367, 1175368, 1175369, 1175370, 1175371,
#        1175372, 1178393, 1178394, 1178395, 1178396, 1178397, 1178398,
#        1178399, 1178400, 1178401, 1178402, 1178403, 1178404, 1178405,
#        1178406, 1178407, 1178408, 1178409, 1178410, 1178411, 1178412,
#        1178413, 1178414, 1178415, 1178416, 1178417, 1178418, 1178419,
#        1178420, 1178421, 1178422, 1178423, 1178424, 1178425, 1178426,
#        1178427, 1178428, 1178429, 1178430, 1178431, 1181764, 1181766,
#        1181767, 1181768, 1216492, 1216493, 1216534, 1216496, 1216508,
#        1216510, 1216539, 1216545, 1216527, 1216547, 1216532, 1216504,
#        1216503, 1216516, 1216514, 1216515, 1216513, 1216538, 1216519,
#        1216511, 1216501, 1216542, 1216500, 1216523, 1216525, 1216507,
#        1216529, 1216540, 1216528, 1216543, 1216531, 1216526, 1216509,
#        1216522, 1216512, 1216517, 1216533, 1216546, 1216494, 1216518,
#        1216521, 1216497, 1216498, 1216541, 1216544, 1216520, 1216524,
#        1216499, 1216536, 1216537, 1216502, 1216535, 1216506, 1216530,
#        1216505, 1216495, 1237177, 1237178, 1237180, 1237181, 1254058,
#        1254059, 1254060, 1254061, 1254062, 1254063, 1254064, 1254065,
#        1254066, 1254067, 1254068, 1254069, 1254070, 1254071, 1254072,
#        1254073, 1254074, 1254075, 1254076, 1254077, 1254078, 1254079,
#        1254080, 1254081, 1254082, 1254083, 1254084, 1254085, 1254086,
#        1254104, 1254087, 1254111, 1254105, 1254096, 1254113, 1254097,
#        1254107, 1254098, 1254108, 1254100, 1254092, 1254099, 1254103,
#        1254091, 1254102, 1254089, 1254112, 1254090, 1254109, 1254110,
#        1254093, 1254095, 1254094, 1254106, 1254088, 1254101, 1254114,
#        1254115, 1254116, 1254117, 1304047, 1304048, 1304049, 1304050,
#        1304051, 1304052, 1304053, 1304054, 1304055, 1304056, 1304057,
#        1304058, 1304059, 1304060, 1304061, 1304062, 1304063, 1304064,
#        1304065, 1304066, 1304067, 1304068, 1304069, 1304070, 1304071,
#        1304072, 1304073, 1304074, 1304075, 1304076, 1304077, 1304078,
#        1304079, 1304080, 1304081, 1304082, 1304083, 1304084, 1304085,
#        1304086, 1304087, 1304088, 1304089, 1304090, 1304091, 1304092,
#        1304093, 1304094, 1304095, 1304096, 1304097, 1304098, 1304099,
#        1304100, 1304101, 1304102, 1304103, 1304104, 1304105, 1304106,
#        1304107, 1304108, 1304109, 1304110, 1304111, 1304112, 1304113,
#        1304114, 1304115, 1304116, 1312197, 1312198, 1312199, 1312200,
#        1359475, 1359477, 1359478, 1359479, 1359480, 1359481, 1359482,
#        1359483, 1359484, 1359485, 1359486, 1359487, 1359488, 1359489,
#        1359490, 1359491, 1359492, 1359493, 1359494, 1359495, 1359496,
#        1359497, 1359498, 1359499, 1359500, 1359501, 1359502, 1359503,
#        1359504, 1359505, 1359506, 1359507, 1359508, 1359509, 1359510,
#        1359511, 1359512, 1359513, 1359514, 1359515, 1359516, 1359517,
#        1359518, 1359520, 1359521, 1359522, 1359523, 1359524, 1359525,
#        1359526, 1359527, 1359528, 1359529, 1359530, 1359531, 1359532,
#        1359533, 1359534, 1359535, 1359536, 1359537, 1359538, 1359539,
#        1359540, 1359541, 1359542, 1359543, 1359544, 1370350, 1370351,
#        1370352], dtype=int64)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(18,8))
plt.plot(temp_df['end_of_over'],temp_df['wickets_in_over'],color='yellow',linewidth=3)
plt.plot(temp_df['end_of_over'],temp_df['win'],color='#00a65a',linewidth=4)
plt.plot(temp_df['end_of_over'],temp_df['lose'],color='red',linewidth=4)
plt.bar(temp_df['end_of_over'],temp_df['runs_after_over'])
plt.title('Target-' + str(target))
# Out:
# Text(0.5, 1.0, 'Target-148')

# %%
teams
# Out:
# ['Sunrisers Hyderabad',
#  'Mumbai Indians',
#  'Royal Challengers Bangalore',
#  'Kolkata Knight Riders',
#  'Punjab Kings',
#  'Chennai Super Kings',
#  'Rajasthan Royals',
#  'Delhi Capitals',
#  'Lucknow Super Giants',
#  'Gujarat Titans']

# %%
delivery_df['city'].unique()
# Out:
# array(['Bangalore', 'Chandigarh', 'Delhi', 'Mumbai', 'Kolkata', 'Jaipur',
#        'Hyderabad', 'Chennai', 'Cape Town', 'Port Elizabeth', 'Durban',
#        'Centurion', 'East London', 'Johannesburg', 'Kimberley',
#        'Bloemfontein', 'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala',
#        'Visakhapatnam', 'Pune', 'Raipur', 'Ranchi', 'Abu Dhabi', nan,
#        'Bengaluru', 'Indore', 'Dubai', 'Sharjah', 'Navi Mumbai',
#        'Lucknow', 'Guwahati'], dtype=object)

# %% [markdown]
# ## PIPE OBJECT

# %%
import pickle

# %%
pickle.dump(pipe, open('pipe.pkl', 'wb'))

# %%
pipe
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])
